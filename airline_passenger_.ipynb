# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # load and check data

# %%
train_df = pd.read_csv('/content/airline train data.csv')

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
train_df.shape
# Out:
# (103904, 25)

# %%
train_df.drop('Unnamed: 0',axis =1,inplace =True)

# %%
train_df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
train_df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
#  11  Food and drink                     103904 non-null  int64
#  12  Online boarding                    103904 non-null  int64
#  13  Seat comfort                       103904 non-null  int64
#  14  Inflight entertainment             103904 non-null  int64
#  15  On-board service                   103904 non-null  int64
#  16  Leg room service                   103904 non-null  int64
#  17  Baggage handling                   103904 non-null  int64
#  18  Checkin service                    103904 non-null  int64
#  19  Inflight service                   103904 non-null  int64
#  20  Cleanliness                        103904 non-null  int64
#  21  Departure Delay in Minutes         103904 non-null  int64
#  22  Arrival Delay in Minutes           103594 non-null  float64
#  23  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 19.0+ MB

# %%
train_df.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  103904.000000   103904.000000    103904.000000  103904.000000
# mean        2.976883        3.202129         3.250375       3.439396
# std         1.277621        1.329533         1.349509       1.319088
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           103904.000000     103904.000000     103904.000000
# mean                 3.358158          3.382363          3.351055
# std                  1.332991          1.288354          1.315605
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     103904.000000    103904.000000     103904.000000  103904.000000
# mean           3.631833         3.304290          3.640428       3.286351
# std            1.180903         1.265396          1.175663       1.312273
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               103904.000000             103594.000000
# mean                    14.815618                 15.178678
# std                     38.230901                 38.698682
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
def bar_plot(variable):

  var = train_df[variable]
  var_value = var.value_counts()

  plt.figure(figsize=(9,3))
  plt.bar(var_value.index,var_value.values)
  plt.xlabel('passengers score')
  plt.ylabel('Frequency')
  plt.title(variable)
  plt.show()

  print("{}:\n {}".format(variable,var_value))

# %%
train_df.select_dtypes(include = ["int64"]).columns
# Out:
# Index(['id', 'Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes'],
#       dtype='object')

# %%
category1=["Inflight wifi service", "Departure/Arrival time convenient", "Ease of Online booking", "Gate location", "Food and drink", "Online boarding", "Seat comfort", "Inflight entertainment", "On-board service", "Leg room service", "Baggage handling", "Checkin service", "Inflight service", "Cleanliness",]
for c in category1:
    bar_plot(c)
# Out:
# Inflight wifi service:
#  3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: Inflight wifi service, dtype: int64
# Departure/Arrival time convenient:
#  4    25546
# 5    22403
# 3    17966
# 2    17191
# 1    15498
# 0     5300
# Name: Departure/Arrival time convenient, dtype: int64
# Ease of Online booking:
#  3    24449
# 2    24021
# 4    19571
# 1    17525
# 5    13851
# 0     4487
# Name: Ease of Online booking, dtype: int64
# Gate location:
#  3    28577
# 4    24426
# 2    19459
# 1    17562
# 5    13879
# 0        1
# Name: Gate location, dtype: int64
# Food and drink:
#  4    24359
# 5    22313
# 3    22300
# 2    21988
# 1    12837
# 0      107
# Name: Food and drink, dtype: int64
# Online boarding:
#  4    30762
# 3    21804
# 5    20713
# 2    17505
# 1    10692
# 0     2428
# Name: Online boarding, dtype: int64
# Seat comfort:
#  4    31765
# 5    26470
# 3    18696
# 2    14897
# 1    12075
# 0        1
# Name: Seat comfort, dtype: int64
# Inflight entertainment:
#  4    29423
# 5    25213
# 3    19139
# 2    17637
# 1    12478
# 0       14
# Name: Inflight entertainment, dtype: int64
# On-board service:
#  4    30867
# 5    23648
# 3    22833
# 2    14681
# 1    11872
# 0        3
# Name: On-board service, dtype: int64
# Leg room service:
#  4    28789
# 5    24667
# 3    20098
# 2    19525
# 1    10353
# 0      472
# Name: Leg room service, dtype: int64
# Baggage handling:
#  4    37383
# 5    27131
# 3    20632
# 2    11521
# 1     7237
# Name: Baggage handling, dtype: int64
# Checkin service:
#  4    29055
# 3    28446
# 5    20619
# 2    12893
# 1    12890
# 0        1
# Name: Checkin service, dtype: int64
# Inflight service:
#  4    37945
# 5    27116
# 3    20299
# 2    11457
# 1     7084
# 0        3
# Name: Inflight service, dtype: int64
# Cleanliness:
#  4    27179
# 3    24574
# 5    22689
# 2    16132
# 1    13318
# 0       12
# Name: Cleanliness, dtype: int64

# %%
catagory2 = ["Gender", "Customer Type", "Type of Travel", "Class","satisfaction"]
for c in catagory2:
  bar_plot(c)
# Out:
# Gender:
#  Female    52727
# Male      51177
# Name: Gender, dtype: int64
# Customer Type:
#  Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# Type of Travel:
#  Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# Class:
#  Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
# satisfaction:
#  neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
def plot_hist(variable):
  plt.figure(figsize=(9,4))
  plt.hist(train_df[variable],bins=50)
  plt.xlabel(variable)
  plt.ylabel("Frequency")
  plt.title("{} distribution with histogram".format(variable))
  plt.show()

# %%
numericvar = ["id","Age", "Flight Distance", "Departure Delay in Minutes", "Arrival Delay in Minutes"]
for n in numericvar:
  plot_hist(n)

# %%
train_df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
train_df.columns = [each.replace(" ","_") for each in train_df.columns]

# %%
train_df['satisfaction'] = [1 if each =='satisfied' else 0 for each in train_df.satisfaction]

# %%
train_df.head(5)
# Out:
#        id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight_Distance  Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#    satisfaction
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
#
# [5 rows x 24 columns]

# %%
# gender vs satisfication
train_df[['Gender','satisfaction']].groupby(['Gender'],as_index=False).mean().sort_values(by='satisfaction',ascending = False)
# Out:
#    Gender  satisfaction
# 1    Male      0.439475
# 0  Female      0.427371

# %%
train_df[['Age','satisfaction']].groupby(['Age'],as_index = False).mean().sort_values(by='satisfaction',ascending =False)
# Out:
#     Age  satisfaction
# 34   41      0.607899
# 39   46      0.599819
# 44   51      0.597249
# 50   57      0.590102
# 45   52      0.586207
# ..  ...           ...
# 2     9      0.137283
# 63   70      0.136143
# 3    10      0.131772
# 1     8      0.107813
# 0     7      0.099644
#
# [75 rows x 2 columns]

# %%
train_df[['Type_of_Travel','satisfaction']].groupby(['Type_of_Travel']).mean().sort_values(by='satisfaction',ascending = False)
# Out:
#                  satisfaction
# Type_of_Travel
# Business travel      0.582597
# Personal Travel      0.101678

# %%
train_df[['Class','satisfaction']].groupby(['Class']).mean().sort_values(by='satisfaction',ascending =False)
# Out:
#           satisfaction
# Class
# Business      0.694251
# Eco Plus      0.246064
# Eco           0.186138

# %%
train_df[['Customer_Type','satisfaction']].groupby(['Customer_Type']).mean().sort_values(by='satisfaction',ascending= False)
# Out:
#                    satisfaction
# Customer_Type
# Loyal Customer         0.477291
# disloyal Customer      0.236658

# %%
# Cleanliness vs satisfaction
train_df[["Cleanliness","satisfaction"]].groupby(["Cleanliness"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Cleanliness  satisfaction
# 5            5      0.608797
# 4            4      0.535340
# 3            3      0.431879
# 2            2      0.212993
# 1            1      0.196201
# 0            0      0.000000

# %%
# Inflight_wifi_service vs satisfaction
train_df[["Inflight_wifi_service","satisfaction"]].groupby(["Inflight_wifi_service"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Inflight_wifi_service  satisfaction
# 0                      0      0.997422
# 5                      5      0.990758
# 4                      4      0.598969
# 1                      1      0.325448
# 3                      3      0.250580
# 2                      2      0.248664

# %%
# Inflight_entertainment vs satisfaction
train_df[["Inflight_entertainment","satisfaction"]].groupby(["Inflight_entertainment"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Inflight_entertainment  satisfaction
# 5                       5      0.648435
# 4                       4      0.611766
# 3                       3      0.270077
# 2                       2      0.213302
# 1                       1      0.139846
# 0                       0      0.000000

# %%
# Food_and_drink vs satisfaction
train_df[["Food_and_drink","satisfaction"]].groupby(["Food_and_drink"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Food_and_drink  satisfaction
# 5               5      0.549007
# 4               4      0.524981
# 0               0      0.467290
# 3               3      0.396368
# 2               2      0.387939
# 1               1      0.200047

# %%
# Seat_comfort vs satisfaction
train_df[["Seat_comfort","satisfaction"]].groupby(["Seat_comfort"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Seat_comfort  satisfaction
# 5             5      0.650208
# 4             4      0.561152
# 2             2      0.224139
# 1             1      0.223188
# 3             3      0.211543
# 0             0      0.000000

# %%
# detecting outlier
numeric_features = train_df.select_dtypes(exclude=['object']).drop(['satisfaction'],axis=1).copy()
numeric_features
# Out:
#             id  Age  Flight_Distance  Inflight_wifi_service  \
# 0        70172   13              460                      3
# 1         5047   25              235                      3
# 2       110028   26             1142                      2
# 3        24026   25              562                      2
# 4       119299   61              214                      3
# ...        ...  ...              ...                    ...
# 103899   94171   23              192                      2
# 103900   73097   49             2347                      4
# 103901   68825   30             1995                      1
# 103902   54173   22             1000                      1
# 103903   62567   27             1723                      1
#
#         Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate_location  Food_and_drink  Online_boarding  Seat_comfort  \
# 0                   1               5                3             5
# 1                   3               1                3             1
# 2                   2               5                5             5
# 3                   5               2                2             2
# 4                   3               4                5             5
# ...               ...             ...              ...           ...
# 103899              3               2                2             2
# 103900              4               2                4             5
# 103901              3               4                1             5
# 103902              5               1                1             1
# 103903              3               1                1             1
#
#         Inflight_entertainment  On-board_service  Leg_room_service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
# [103904 rows x 19 columns]

# %%
numeric_features.columns
# Out:
# Index(['id', 'Age', 'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes',
#        'Arrival_Delay_in_Minutes'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(12,18))
for i in range(len(numeric_features.columns)):
  fig.add_subplot(9,4,i+1)
  sns.boxplot(y=numeric_features.iloc[:,i])


plt.tight_layout()
plt.show()

# %%
def detect_outliers(df,features):
    outlier_indices=[]

    for c in features:
        # 1st quartile
        Q1=np.percentile(df[c],25)

        # 3rd quartile
        Q3=np.percentile(df[c],75)

        # IQR
        IQR= Q3-Q1

        # Outlier Step
        outlier_step= IQR * 1.5

        # Detect outlier and their indeces
        outlier_list_col = df[(df[c]< Q1 - outlier_step)|( df[c] > Q3 + outlier_step)].index

        # Store indices
        outlier_indices.extend(outlier_list_col)

    outliers_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i , v in outliers_indices.items() if v>2 )
    return multiple_outliers

# %%
from collections import Counter

# %%
train_df.loc[detect_outliers(train_df,[ 'Age', 'Flight_Distance', 'Inflight_wifi_service',
       'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
       'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
       'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Inflight_service',
       'Cleanliness', 'Departure_Delay_in_Minutes',
       'Arrival_Delay_in_Minutes'])]
# Out:
#             id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 1876     66058    Male     Loyal Customer   66  Business travel  Business
# 2363     14315  Female     Loyal Customer   55  Business travel  Business
# 2970    120215  Female     Loyal Customer   13  Business travel  Business
# 5639    106154    Male     Loyal Customer   37  Business travel  Business
# 5732     70437  Female     Loyal Customer   54  Business travel  Business
# 14195    14938    Male     Loyal Customer   33  Business travel  Business
# 14306    73409  Female     Loyal Customer   61  Business travel  Business
# 18509   110386  Female     Loyal Customer    9  Business travel  Business
# 20311    45906    Male     Loyal Customer   36  Business travel  Business
# 21191    74135  Female     Loyal Customer   45  Business travel  Business
# 21734   105705  Female     Loyal Customer   27  Business travel  Business
# 23408    49474  Female     Loyal Customer   42  Business travel  Business
# 23602    20916  Female     Loyal Customer   24  Business travel  Business
# 25877    72017    Male  disloyal Customer   34  Business travel  Business
# 30330    92871  Female     Loyal Customer   54  Business travel  Business
# 35574    17551  Female     Loyal Customer   38  Business travel  Business
# 38642    16863  Female     Loyal Customer   59  Business travel  Business
# 38677    18140  Female     Loyal Customer   53  Business travel  Business
# 41931    55887    Male     Loyal Customer   23  Business travel  Business
# 42364    69415    Male     Loyal Customer   66  Business travel  Business
# 43775   113506    Male     Loyal Customer   29  Business travel  Business
# 44822    19879  Female     Loyal Customer   54  Business travel  Business
# 56738    96855    Male     Loyal Customer   45  Business travel  Business
# 57171    44682    Male     Loyal Customer   31  Business travel  Business
# 61794    35835    Male     Loyal Customer   56  Business travel  Business
# 63522   115739  Female     Loyal Customer   60  Business travel  Business
# 71752    58176    Male     Loyal Customer   36  Business travel  Business
# 71967    37417  Female     Loyal Customer   37  Business travel  Business
# 72278   109884  Female     Loyal Customer   37  Business travel  Business
# 73622    22824    Male     Loyal Customer   40  Business travel  Business
# 77035    77703  Female     Loyal Customer   27  Business travel  Business
# 77247    48882  Female     Loyal Customer   63  Business travel  Business
# 79812   112897    Male     Loyal Customer   16  Business travel  Business
# 80617   102261  Female     Loyal Customer   32  Business travel  Business
# 85138   124461  Female     Loyal Customer   28  Business travel  Business
# 89176    50130    Male     Loyal Customer   44  Business travel  Business
# 94602    19491  Female     Loyal Customer   42  Business travel  Business
# 96436    26321  Female     Loyal Customer   49  Business travel  Business
# 97569     7662    Male     Loyal Customer   51  Business travel  Business
# 101448  123154  Female     Loyal Customer   32  Business travel  Business
#
#         Flight_Distance  Inflight_wifi_service  \
# 1876               3829                      3
# 2363               3861                      2
# 2970               3990                      3
# 5639               3990                      3
# 5732               3801                      1
# 14195              3891                      3
# 14306              3861                      3
# 18509              3814                      2
# 20311              3901                      3
# 21191              3897                      1
# 21734              3883                      4
# 23408              3854                      3
# 23602              3798                      1
# 25877              3784                      3
# 30330              3894                      0
# 35574              3844                      2
# 38642              3975                      1
# 38677              3777                      3
# 41931              3951                      1
# 42364              3915                      1
# 43775              3887                      3
# 44822              3774                      4
# 56738              3815                      1
# 57171              3758                      1
# 61794              4000                      1
# 63522              3915                      2
# 71752              3930                      1
# 71967              3876                      1
# 72278              3951                      1
# 73622              3983                      4
# 77035              3953                      4
# 77247              3795                      1
# 79812              3922                      1
# 80617              3875                      1
# 85138              3930                      2
# 89176              3997                      2
# 94602              3737                      2
# 96436              3848                      2
# 97569              3923                      2
# 101448             3783                      2
#
#         Departure/Arrival_time_convenient  Ease_of_Online_booking  ...  \
# 1876                                    5                       5  ...
# 2363                                    1                       1  ...
# 2970                                    5                       2  ...
# 5639                                    5                       5  ...
# 5732                                    5                       5  ...
# 14195                                   3                       3  ...
# 14306                                   3                       3  ...
# 18509                                   3                       4  ...
# 20311                                   1                       1  ...
# 21191                                   5                       5  ...
# 21734                                   2                       2  ...
# 23408                                   5                       5  ...
# 23602                                   2                       2  ...
# 25877                                   3                       3  ...
# 30330                                   5                       1  ...
# 35574                                   2                       2  ...
# 38642                                   1                       1  ...
# 38677                                   3                       3  ...
# 41931                                   1                       5  ...
# 42364                                   1                       1  ...
# 43775                                   5                       5  ...
# 44822                                   4                       4  ...
# 56738                                   0                       0  ...
# 57171                                   4                       4  ...
# 61794                                   1                       1  ...
# 63522                                   5                       5  ...
# 71752                                   5                       5  ...
# 71967                                   1                       1  ...
# 72278                                   4                       4  ...
# 73622                                   1                       1  ...
# 77035                                   4                       4  ...
# 77247                                   1                       1  ...
# 79812                                   1                       5  ...
# 80617                                   3                       3  ...
# 85138                                   1                       1  ...
# 89176                                   1                       1  ...
# 94602                                   4                       4  ...
# 96436                                   4                       4  ...
# 97569                                   4                       2  ...
# 101448                                  1                       3  ...
#
#         Inflight_entertainment  On-board_service  Leg_room_service  \
# 1876                         3                 3                 3
# 2363                         2                 2                 3
# 2970                         3                 4                 1
# 5639                         3                 3                 2
# 5732                         4                 4                 3
# 14195                        5                 4                 4
# 14306                        5                 5                 5
# 18509                        2                 3                 1
# 20311                        3                 3                 3
# 21191                        4                 2                 4
# 21734                        4                 1                 5
# 23408                        1                 1                 1
# 23602                        2                 5                 3
# 25877                        3                 5                 3
# 30330                        5                 5                 4
# 35574                        2                 2                 2
# 38642                        5                 5                 5
# 38677                        5                 5                 5
# 41931                        4                 5                 3
# 42364                        5                 5                 4
# 43775                        3                 3                 4
# 44822                        4                 4                 4
# 56738                        2                 2                 0
# 57171                        1                 3                 5
# 61794                        4                 4                 4
# 63522                        2                 2                 2
# 71752                        1                 1                 1
# 71967                        1                 1                 1
# 72278                        1                 1                 1
# 73622                        3                 3                 3
# 77035                        4                 1                 1
# 77247                        4                 4                 4
# 79812                        1                 4                 2
# 80617                        4                 4                 3
# 85138                        2                 4                 5
# 89176                        3                 3                 3
# 94602                        2                 2                 2
# 96436                        2                 2                 3
# 97569                        2                 2                 2
# 101448                       2                 2                 2
#
#         Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 1876                   3                1                 3            3
# 2363                   2                1                 2            1
# 2970                   3                1                 3            3
# 5639                   3                1                 3            2
# 5732                   1                1                 4            4
# 14195                  1                1                 4            5
# 14306                  5                1                 5            4
# 18509                  4                1                 3            2
# 20311                  3                1                 3            2
# 21191                  3                1                 1            1
# 21734                  3                1                 4            4
# 23408                  3                1                 1            3
# 23602                  4                1                 1            1
# 25877                  4                1                 4            1
# 30330                  4                1                 3            1
# 35574                  2                1                 2            1
# 38642                  5                1                 5            3
# 38677                  5                1                 5            2
# 41931                  3                1                 4            1
# 42364                  5                1                 5            4
# 43775                  3                1                 4            3
# 44822                  4                1                 4            1
# 56738                  2                1                 2            1
# 57171                  4                1                 3            1
# 61794                  4                1                 4            5
# 63522                  2                1                 2            1
# 71752                  1                1                 1            1
# 71967                  1                1                 1            1
# 72278                  1                1                 1            1
# 73622                  4                1                 3            2
# 77035                  3                1                 4            4
# 77247                  4                1                 4            5
# 79812                  3                1                 4            1
# 80617                  2                1                 2            1
# 85138                  3                1                 3            2
# 89176                  2                1                 3            4
# 94602                  2                1                 2            4
# 96436                  2                1                 2            2
# 97569                  2                1                 2            4
# 101448                 3                1                 3            2
#
#         Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction
# 1876                            42                      41.0             0
# 2363                            42                      39.0             0
# 2970                            36                      19.0             0
# 5639                            44                      40.0             0
# 5732                            38                      28.0             0
# 14195                           84                      79.0             1
# 14306                           42                      45.0             1
# 18509                           83                      83.0             0
# 20311                           75                      71.0             0
# 21191                          123                     134.0             0
# 21734                           59                      69.0             0
# 23408                           38                      33.0             0
# 23602                          177                     167.0             0
# 25877                          239                     226.0             0
# 30330                          237                     228.0             1
# 35574                          108                      93.0             0
# 38642                           45                      17.0             1
# 38677                           33                       NaN             1
# 41931                          151                     126.0             0
# 42364                           62                      70.0             1
# 43775                           38                      32.0             0
# 44822                           31                      15.0             1
# 56738                           71                      72.0             0
# 57171                           68                      56.0             0
# 61794                           47                      55.0             1
# 63522                           86                      88.0             0
# 71752                           93                      72.0             0
# 71967                           33                      30.0             0
# 72278                           45                      41.0             0
# 73622                           39                      24.0             0
# 77035                           36                      43.0             0
# 77247                           93                      95.0             1
# 79812                           52                      49.0             0
# 80617                          171                     176.0             0
# 85138                           53                     109.0             0
# 89176                           59                      59.0             0
# 94602                           41                      50.0             0
# 96436                           67                      70.0             0
# 97569                           35                      63.0             0
# 101448                          54                      51.0             0
#
# [40 rows x 24 columns]

# %%
train_df.shape
# Out:
# (103904, 24)

# %%
train_df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer_Type                          0
# Age                                    0
# Type_of_Travel                         0
# Class                                  0
# Flight_Distance                        0
# Inflight_wifi_service                  0
# Departure/Arrival_time_convenient      0
# Ease_of_Online_booking                 0
# Gate_location                          0
# Food_and_drink                         0
# Online_boarding                        0
# Seat_comfort                           0
# Inflight_entertainment                 0
# On-board_service                       0
# Leg_room_service                       0
# Baggage_handling                       0
# Checkin_service                        0
# Inflight_service                       0
# Cleanliness                            0
# Departure_Delay_in_Minutes             0
# Arrival_Delay_in_Minutes             310
# satisfaction                           0
# dtype: int64

# %%
train_df = train_df.dropna(axis=0)

# %%
train_df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %%
train_df.shape
# Out:
# (103594, 24)

# %%
plt.figure(figsize=(10,10))
list1=["Age",'Inflight_wifi_service',
       'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
       'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
       'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Inflight_service',
       'Cleanliness',"satisfaction"]
sns.heatmap(train_df[list1].corr(),annot=True,fmt=".2f")
plt.show()

# %%
g=sns.catplot(x="Gender",y="satisfaction",data=train_df,kind="bar")
g.set_ylabels("Satisfaction Probability")
plt.show()

# %%
g= sns.FacetGrid(train_df,col="satisfaction")
g.map(sns.distplot,"Age",bins=25)
plt.show()
# 0=neutral or dissatisfied, 1=satisfied

# %%
g=sns.catplot(x="Customer_Type",y="satisfaction",data=train_df,kind="bar")
g.set_ylabels("Satisfaction Probability")
plt.show()

# %%
g=sns.catplot(x="Type_of_Travel",y="satisfaction",data=train_df,kind="bar")
g.set_ylabels("Satisfaction Probability")
plt.show()

# %%
g=sns.catplot(x="Class",y="satisfaction",data=train_df,kind="bar")
g.set_ylabels("Satisfation Probability")
plt.show()

# %%
personal=train_df[train_df.Type_of_Travel=="Personal Travel"]
personal.head()
# Out:
#         id  Gender   Customer_Type  Age   Type_of_Travel     Class  \
# 0    70172    Male  Loyal Customer   13  Personal Travel  Eco Plus
# 5   111157  Female  Loyal Customer   26  Personal Travel       Eco
# 6    82113    Male  Loyal Customer   47  Personal Travel       Eco
# 11   51412  Female  Loyal Customer   12  Personal Travel  Eco Plus
# 13   83502    Male  Loyal Customer   33  Personal Travel       Eco
#
#     Flight_Distance  Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0               460                      3                                  4
# 5              1180                      3                                  4
# 6              1276                      2                                  4
# 11              308                      2                                  4
# 13              946                      4                                  2
#
#     Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# 0                        3  ...                       5                 4
# 5                        2  ...                       1                 3
# 6                        2  ...                       2                 3
# 11                       2  ...                       1                 1
# 13                       4  ...                       4                 4
#
#     Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# 0                  3                 4                4                 5
# 5                  4                 4                4                 4
# 6                  3                 4                3                 5
# 11                 2                 5                5                 5
# 13                 5                 2                2                 2
#
#     Cleanliness  Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  \
# 0             5                          25                      18.0
# 5             1                           0                       0.0
# 6             2                           9                      23.0
# 11            1                           0                       0.0
# 13            4                           0                       0.0
#
#     satisfaction
# 0              0
# 5              0
# 6              0
# 11             0
# 13             1
#
# [5 rows x 24 columns]

# %%
def service_plot(variable):

    var=personal[variable]
    var_Value=var.value_counts()

    #visualize
    plt.figure(figsize=(9,3))
    plt.bar(var_Value.index,var_Value.values)

    plt.xlabel("Passengers Score")
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,var_Value))

# %%
service=["On-board_service", "Leg_room_service", "Checkin_service","Inflight_service"]

for c in service:
    service_plot(c)
# Out:
# On-board_service:
#  3    8394
# 4    8329
# 5    6699
# 2    4494
# 1    4213
# Name: On-board_service, dtype: int64
# Leg_room_service:
#  3    7753
# 2    7505
# 4    6945
# 5    5840
# 1    3687
# 0     399
# Name: Leg_room_service, dtype: int64
# Checkin_service:
#  4    9113
# 3    8938
# 5    6526
# 1    3802
# 2    3750
# Name: Checkin_service, dtype: int64
# Inflight_service:
#  4    11287
# 5     8454
# 3     6182
# 2     3537
# 1     2669
# Name: Inflight_service, dtype: int64

# %%
sns.countplot(x="Customer_Type",data=train_df)
# Out:
# <Axes: xlabel='Customer_Type', ylabel='count'>

# %%
train_df=pd.get_dummies(train_df,columns=["Customer_Type"])
train_df.head()
# Out:
#        id  Gender  Age   Type_of_Travel     Class  Flight_Distance  \
# 0   70172    Male   13  Personal Travel  Eco Plus              460
# 1    5047    Male   25  Business travel  Business              235
# 2  110028  Female   26  Business travel  Business             1142
# 3   24026  Female   25  Business travel  Business              562
# 4  119299    Male   61  Business travel  Business              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Leg_room_service  \
# 0                       3              1  ...                 3
# 1                       3              3  ...                 5
# 2                       2              2  ...                 3
# 3                       5              5  ...                 5
# 4                       3              3  ...                 4
#
#    Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Customer_Type_Loyal Customer  Customer_Type_disloyal Customer
# 0                             1                                0
# 1                             0                                1
# 2                             1                                0
# 3                             1                                0
# 4                             1                                0
#
# [5 rows x 25 columns]

# %%
sns.countplot(x="Type_of_Travel",data=train_df)
# Out:
# <Axes: xlabel='Type_of_Travel', ylabel='count'>

# %%
train_df=pd.get_dummies(train_df,columns=["Type_of_Travel"])
train_df.head()
# Out:
#        id  Gender  Age     Class  Flight_Distance  Inflight_wifi_service  \
# 0   70172    Male   13  Eco Plus              460                      3
# 1    5047    Male   25  Business              235                      3
# 2  110028  Female   26  Business             1142                      2
# 3   24026  Female   25  Business              562                      2
# 4  119299    Male   61  Business              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  ...  Checkin_service  Inflight_service  Cleanliness  \
# 0               5  ...                4                 5            5
# 1               1  ...                1                 4            1
# 2               5  ...                4                 4            5
# 3               2  ...                1                 4            2
# 4               4  ...                3                 3            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 0                             1                                0
# 1                             0                                1
# 2                             1                                0
# 3                             1                                0
# 4                             1                                0
#
#    Type_of_Travel_Business travel  Type_of_Travel_Personal Travel
# 0                               0                               1
# 1                               1                               0
# 2                               1                               0
# 3                               1                               0
# 4                               1                               0
#
# [5 rows x 26 columns]

# %%
sns.barplot(x=train_df.Class.value_counts().values,y=train_df.Class.value_counts().index)
plt.xlabel("Number of Passenger")
plt.show()

# %%
sns.barplot(x=train_df.Class.value_counts().values,y=train_df.Class.value_counts().index)
plt.xlabel("Number of Passenger")
plt.show()

# %%
train_df=pd.get_dummies(train_df,columns=["Gender"])
train_df.head()
# Out:
#        id  Age     Class  Flight_Distance  Inflight_wifi_service  \
# 0   70172   13  Eco Plus              460                      3
# 1    5047   25  Business              235                      3
# 2  110028   26  Business             1142                      2
# 3   24026   25  Business              562                      2
# 4  119299   61  Business              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  Online_boarding  ...  Cleanliness  \
# 0               5                3  ...            5
# 1               1                3  ...            1
# 2               5                5  ...            5
# 3               2                2  ...            2
# 4               4                5  ...            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 0                             1                                0
# 1                             0                                1
# 2                             1                                0
# 3                             1                                0
# 4                             1                                0
#
#    Type_of_Travel_Business travel  Type_of_Travel_Personal Travel  \
# 0                               0                               1
# 1                               1                               0
# 2                               1                               0
# 3                               1                               0
# 4                               1                               0
#
#    Gender_Female  Gender_Male
# 0              0            1
# 1              0            1
# 2              1            0
# 3              1            0
# 4              0            1
#
# [5 rows x 27 columns]

# %%
train_df.drop(labels=["id"],axis=1,inplace=True)

# %%
train_df.head()
# Out:
#    Age     Class  Flight_Distance  Inflight_wifi_service  \
# 0   13  Eco Plus              460                      3
# 1   25  Business              235                      3
# 2   26  Business             1142                      2
# 3   25  Business              562                      2
# 4   61  Business              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  Online_boarding  Seat_comfort  ...  Cleanliness  \
# 0               5                3             5  ...            5
# 1               1                3             1  ...            1
# 2               5                5             5  ...            5
# 3               2                2             2  ...            2
# 4               4                5             5  ...            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 0                             1                                0
# 1                             0                                1
# 2                             1                                0
# 3                             1                                0
# 4                             1                                0
#
#    Type_of_Travel_Business travel  Type_of_Travel_Personal Travel  \
# 0                               0                               1
# 1                               1                               0
# 2                               1                               0
# 3                               1                               0
# 4                               1                               0
#
#    Gender_Female  Gender_Male
# 0              0            1
# 1              0            1
# 2              1            0
# 3              1            0
# 4              0            1
#
# [5 rows x 26 columns]

# %% [markdown]
# Modeling
# Algorithms that we will use when creating our model;
# Logistic Regression
# Random Forest Classifer
# Decision Tree Classifer
# KNeighbors Classifer

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
len(train_df)
# Out:
# 103594

# %%
train_df['Class'].map({'Eco':0,'Business':1,'Eco Plus':2})
# Out:
# 0         2
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 103899    0
# 103900    1
# 103901    1
# 103902    0
# 103903    1
# Name: Class, Length: 103594, dtype: int64

# %%
X=train_df.drop(labels="satisfaction",axis=1)
y=train_df["satisfaction"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)
print("X_train",len(X_train))
print("X_test",len(X_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
# Out:
# X_train 69407
# X_test 34187
# y_train 69407
# y_test 34187
